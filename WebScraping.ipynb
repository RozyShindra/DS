# %% [markdown]
# Importing important libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Requesting url to be scrapped

# %%
Company_data = pd.DataFrame()
for j in range(1,501):
      url ='https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
      headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
      web= requests.get( url , headers=headers).text
      soup=BeautifulSoup(web ,'lxml')   # lxml for parsing into html easily
      company = soup.find_all('div' , class_= 'companyCardWrapper')
      CompanyName=[]
      Rating =[]
      Reviews=[]
      Salaries=[]
      Interviews=[]
      About =[]
      for i in company:
          CompanyName.append(i.find('h2').text.strip())
          Rating.append(i.find('div', class_ = 'companyCardWrapper__companyRating').text.strip())
          Reviews.append(i.find_all('a', class_ = 'companyCardWrapper__ActionWrapper')[0].text.strip())
          Salaries.append(i.find_all('a', class_ = 'companyCardWrapper__ActionWrapper')[1].text.strip())
          Interviews.append(i.find_all('a', class_ = 'companyCardWrapper__ActionWrapper')[2].text.strip())
          About.append(i.find('div' , class_='companyCardWrapper__interLinkingWrapper').text.strip())

      d = {'CompanyName': CompanyName,
          'Rating' :Rating,
          'Reviews':Reviews,
          'Salaries': Salaries,
          'Interviews' : Interviews,
          'About' :About}
      df=pd.DataFrame(d)
      Company_data=Company_data.append(df , ignore_index=True)
# using header when website do not allow you to get  their data  so you have to use web scraping for getting the data , it will give website illusion that the browser is requesting for the data
# Out:
# <ipython-input-13-33d031388517>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Company_data=Company_data.append(df , ignore_index=True)
# <ipython-input-13-33d031388517>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Company_data=Company_data.append(df , ignore_index=True)
# <ipython-input-13-33d031388517>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Company_data=Company_data.append(df , ignore_index=True)
# <ipython-input-13-33d031388517>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Company_data=Company_data.append(df , ignore_index=True)
# ...

# %%
Company_data.shape
# Out:
# (10000, 6)

# %%
Company_data.head()
# Out:
#   CompanyName Rating        Reviews         Salaries       Interviews  \
# 0         TCS    3.8  67.5k Reviews  737.8k Salaries  5.7k Interviews
# 1   Accenture    4.0  43.1k Reviews  514.1k Salaries    4k Interviews
# 2   Cognizant    3.9  38.8k Reviews  497.3k Salaries  3.3k Interviews
# 3       Wipro    3.8  35.9k Reviews  371.3k Salaries  3.4k Interviews
# 4  ICICI Bank    4.0  31.2k Reviews  136.4k Salaries  1.8k Interviews
#
#                                                About
# 0  IT Services & Consulting | 1 Lakh+ Employees |...
# 1  IT Services & Consulting | 1 Lakh+ Employees |...
# 2  IT Services & Consulting | 1 Lakh+ Employees |...
# 3  IT Services & Consulting | 1 Lakh+ Employees |...
# 4  Banking | 1 Lakh+ Employees | Public | 29 year...
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %% [markdown]
# Storing dataset into csv file

# %%
Company_data.to_csv('Company_data.csv', index=False)
print(open('Company_data.csv', 'r').read())
# Out:
# CompanyName,Rating,Reviews,Salaries,Interviews,About
# TCS,3.8,67.5k Reviews,737.8k Salaries,5.7k Interviews,IT Services & Consulting | 1 Lakh+ Employees | Public | 55 years old | Mumbai +305 more
# Accenture,4.0,43.1k Reviews,514.1k Salaries,4k Interviews,IT Services & Consulting | 1 Lakh+ Employees | Public | 34 years old | Dublin +156 more
# Cognizant,3.9,38.8k Reviews,497.3k Salaries,3.3k Interviews,IT Services & Consulting | 1 Lakh+ Employees | Forbes Global 2000 | 29 years old | Teaneck. New Jersey. +131 more
# Wipro,3.8,35.9k Reviews,371.3k Salaries,3.4k Interviews,IT Services & Consulting | 1 Lakh+ Employees | Public | 78 years old | Bangalore/Bengaluru +259 more
# ICICI Bank,4.0,31.2k Reviews,136.4k Salaries,1.8k Interviews,Banking | 1 Lakh+ Employees | Public | 29 years old | Mumbai +1227 more
# HDFC Bank,3.9,31k Reviews,123.5k Salaries,1.4k Interviews,Banking | 1 Lakh+ Employees | Public | 29 years old | Mumbai +1462 more
# ...

# %%
f= pd.read_csv("/content/Company_data.csv")

# %%
f.shape
# Out:
# (10000, 6)

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CompanyName  10000 non-null  object
#  1   Rating       10000 non-null  float64
#  2   Reviews      10000 non-null  object
#  3   Salaries     10000 non-null  object
#  4   Interviews   10000 non-null  object
#  5   About        10000 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 468.9+ KB

# %%
f
# Out:
#                     CompanyName  Rating        Reviews         Salaries  \
# 0                           TCS     3.8  67.5k Reviews  737.8k Salaries
# 1                     Accenture     4.0  43.1k Reviews  514.1k Salaries
# 2                     Cognizant     3.9  38.8k Reviews  497.3k Salaries
# 3                         Wipro     3.8  35.9k Reviews  371.3k Salaries
# 4                    ICICI Bank     4.0  31.2k Reviews  136.4k Salaries
# ...                         ...     ...            ...              ...
# 9995           Slate The School     4.5     66 Reviews     271 Salaries
# 9996                Rana Motors     4.1     66 Reviews     354 Salaries
# 9997  Pavna Group of Industries     3.4     66 Reviews     382 Salaries
# 9998         Plan International     3.9     66 Reviews     286 Salaries
# 9999               ESDEE PAINTS     2.9     66 Reviews     344 Salaries
#
#            Interviews                                              About
# ...

# %%
# Out:
# (10000, 6)
